# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/data_rank.csv")

# %%
def result_finder(home, away):
    if home > away:
        return pd.Series([0, 3, 0])
    if home < away:
        return pd.Series([1, 0, 3])
    else:
        return pd.Series([2, 1, 1])

results = df.apply(lambda x: result_finder(x["home_score"], x["away_score"]), axis=1)

# %%
df[["result", "home_team_points", "away_team_points"]] = results

# %%
import seaborn as sns

sns.heatmap(df[["total_points_home", "rank_home", "total_points_away", "rank_away"]].corr())
# Out:
# <Axes: >

# %%
df["rank_dif"] = df["rank_home"] - df["rank_away"]
df["sg"] = df["home_score"] - df["away_score"]
df["points_home_by_rank"] = df["home_team_points"]/df["rank_away"]
df["points_away_by_rank"] = df["away_team_points"]/df["rank_home"]

# %%
home_team = df[["date", "home_team", "home_score", "away_score", "rank_home", "rank_away","rank_change_home", "total_points_home", "result", "rank_dif", "points_home_by_rank", "home_team_points"]]

away_team = df[["date", "away_team", "away_score", "home_score", "rank_away", "rank_home","rank_change_away", "total_points_away", "result", "rank_dif", "points_away_by_rank", "away_team_points"]]

# %%
home_team.columns = [h.replace("home_", "").replace("_home", "").replace("away_", "suf_").replace("_away", "_suf") for h in home_team.columns]

away_team.columns = [a.replace("away_", "").replace("_away", "").replace("home_", "suf_").replace("_home", "_suf") for a in away_team.columns]

# %%
team_stats = home_team.append(away_team)#.sort_values("date")
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_8728\3405291978.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_stats = home_team.append(away_team)#.sort_values("date")

# %%
#team_stats.sort_values('date')

# %%
from tqdm import tqdm

# %%
stats_val = []

for index, row in tqdm(team_stats.iterrows()):
    team = row["team"]
    date = row["date"]
    past_games = team_stats.loc[(team_stats["team"] == team) & (team_stats["date"] < date)].sort_values(by=['date'], ascending=False)
    past_games['score_by_rank'] = past_games['score']/past_games['rank_suf']
    past_games['score_suf_by_rank'] = past_games['suf_score']*past_games['rank_suf']
    
    last5 = past_games.head(5)
    
    
    goals = past_games["score"].mean()
    goals_l5 = last5["score"].mean()
    
    goals_suf = past_games["suf_score"].mean()
    goals_suf_l5 = last5["suf_score"].mean()
    
    rank = past_games["rank_suf"].mean()
    rank_l5 = last5["rank_suf"].mean()
    
    goals_by_rank = past_games['score_by_rank'].mean()
    goals_by_rank_l5 = last5['score_by_rank'].mean()
    
    goals_suf_by_rank = past_games['score_suf_by_rank'].mean()
    goals_suf_by_rank_l5 = last5['score_suf_by_rank'].mean()
    
    if len(last5) > 0:
        points = past_games["total_points"].values[0] - past_games["total_points"].values[-1]#qtd de pontos ganhos
        points_l5 = last5["total_points"].values[0] - last5["total_points"].values[-1] 
    else:
        points = 0
        points_l5 = 0
        
    gp = past_games["team_points"].mean()
    gp_l5 = last5["team_points"].mean()
    
    gp_rank = past_games["points_by_rank"].mean()
    gp_rank_l5 = last5["points_by_rank"].mean()
    
    stats_val.append([goals, goals_l5, goals_suf, goals_suf_l5, rank, rank_l5, points, points_l5, gp, gp_l5, gp_rank, gp_rank_l5,
                     goals_by_rank, goals_by_rank_l5, goals_suf_by_rank, goals_suf_by_rank_l5])
# Out:
# 7688it [00:32, 236.16it/s]

# %%
stats_val[-1]
# Out:
# [1.6981132075471699,
#  3.2,
#  1.150943396226415,
#  0.8,
#  55.64150943396226,
#  107.4,
#  53.039999999999964,
#  4.319999999999936,
#  1.6603773584905661,
#  3.0,
#  0.06745783220700337,
#  0.03556001454001719,
#  0.06695901182471393,
#  0.03079451519870203,
#  40.35849056603774,
#  76.0]

# %%
stats_mean = ["goals_mean", "goals_mean_l5", "goals_suf_mean", "goals_suf_mean_l5", "rank_mean", "rank_mean_l5", "points_mean", "points_mean_l5", "game_points_mean", "game_points_mean_l5", "game_points_rank_mean", "game_points_rank_mean_l5", "goals_by_rank", "goals_by_rank_l5", "goals_suf_by_rank", "goals_suf_by_rank_l5"]

# %%
stats_df = pd.DataFrame(stats_val, columns=stats_mean)

full_df = pd.concat([team_stats.reset_index(drop=True), stats_df], axis=1, ignore_index=False)

# %%
home_team_stats = full_df.iloc[:int(full_df.shape[0]/2),:]
away_team_stats = full_df.iloc[int(full_df.shape[0]/2):,:]

# %%
home_team_stats = home_team_stats[home_team_stats.columns[-16:]]
away_team_stats = away_team_stats[away_team_stats.columns[-16:]]

# %%
home_team_stats.columns = ['home_'+str(col) for col in home_team_stats.columns]
away_team_stats.columns = ['away_'+str(col) for col in away_team_stats.columns]

# %%
match_stats = pd.concat([home_team_stats, away_team_stats.reset_index(drop=True)], axis=1, ignore_index=False)

# %%
full_df = pd.concat([df, match_stats.reset_index(drop=True)], axis=1, ignore_index=False)

# %%
full_df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral', 'total_points_home',
#        'previous_points_home', 'rank_home', 'rank_change_home',
#        'total_points_away', 'previous_points_away', 'rank_away',
#        'rank_change_away', 'result', 'home_team_points', 'away_team_points',
#        'rank_dif', 'sg', 'points_home_by_rank', 'points_away_by_rank',
#        'home_goals_mean', 'home_goals_mean_l5', 'home_goals_suf_mean',
#        'home_goals_suf_mean_l5', 'home_rank_mean', 'home_rank_mean_l5',
#        'home_points_mean', 'home_points_mean_l5', 'home_game_points_mean',
#        'home_game_points_mean_l5', 'home_game_points_rank_mean',
#        'home_game_points_rank_mean_l5', 'home_goals_by_rank',
#        'home_goals_by_rank_l5', 'home_goals_suf_by_rank',
#        'home_goals_suf_by_rank_l5', 'away_goals_mean', 'away_goals_mean_l5',
#        'away_goals_suf_mean', 'away_goals_suf_mean_l5', 'away_rank_mean',
#        'away_rank_mean_l5', 'away_points_mean', 'away_points_mean_l5',
#        'away_game_points_mean', 'away_game_points_mean_l5',
#        'away_game_points_rank_mean', 'away_game_points_rank_mean_l5',
#        'away_goals_by_rank', 'away_goals_by_rank_l5', 'away_goals_suf_by_rank',
#        'away_goals_suf_by_rank_l5'],
#       dtype='object')

# %%
def find_friendly(x):
    if x == "Friendly":
        return 1
    else: return 0

full_df["is_friendly"] = full_df["tournament"].apply(lambda x: find_friendly(x))

# %%
full_df = pd.get_dummies(full_df, columns=["is_friendly"])

# %%
base_df = full_df[["date", "home_team", "away_team", "rank_home", "rank_away","home_score", "away_score","result", "rank_dif", "rank_change_home", "rank_change_away", 'home_goals_mean',
       'home_goals_mean_l5', 'home_goals_suf_mean', 'home_goals_suf_mean_l5',
       'home_rank_mean', 'home_rank_mean_l5', 'home_points_mean',
       'home_points_mean_l5', 'away_goals_mean', 'away_goals_mean_l5',
       'away_goals_suf_mean', 'away_goals_suf_mean_l5', 'away_rank_mean',
       'away_rank_mean_l5', 'away_points_mean', 'away_points_mean_l5','home_game_points_mean', 'home_game_points_mean_l5',
       'home_game_points_rank_mean', 'home_game_points_rank_mean_l5','away_game_points_mean',
       'away_game_points_mean_l5', 'away_game_points_rank_mean',
       'away_game_points_rank_mean_l5',
       'home_goals_by_rank','home_goals_by_rank_l5', 'home_goals_suf_by_rank','home_goals_suf_by_rank_l5',
       'away_goals_by_rank','away_goals_by_rank_l5', 'away_goals_suf_by_rank','away_goals_suf_by_rank_l5',
       'is_friendly_0', 'is_friendly_1', "neutral"]]

# %%
base_df_no_fg = base_df.dropna()

# %%
base_df_no_fg.to_csv("data/full_db.csv", index=False)

# %%
df = base_df_no_fg.copy()

# %%
df['total_games_away'] = df.apply(lambda x: len(df[(df.home_team == x["away_team"]) & (df.date < x["date"])])+len(df[(df.away_team == x["away_team"]) & (df.date < x["date"])]), axis=1)

# %%
df['total_games_home'] = df.apply(lambda x: len(df[(df.home_team == x["home_team"]) & (df.date < x["date"])])+len(df[(df.away_team == x["home_team"]) & (df.date < x["date"])]), axis=1)

# %%
df = df[df.rank_home != df.rank_away]

# %%
df['home_weight_goals'] = df.apply(lambda x: (x["home_goals_mean"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_goals_suf'] = df.apply(lambda x: (x["away_goals_suf_mean"]*x["rank_dif"]), axis =1)

# %%
df['home_weight_goals_l5'] = df.apply(lambda x: (x["home_goals_mean_l5"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_goals_suf_l5'] = df.apply(lambda x: (x["away_goals_suf_mean_l5"]*x["rank_dif"]), axis =1)

# %%
df['home_weight_points'] = df.apply(lambda x: (x["home_game_points_mean"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_points'] = df.apply(lambda x: (x["away_game_points_mean"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_goals'] = df.apply(lambda x: (x["away_goals_mean"]*x["rank_dif"]), axis =1)
df['home_weight_goals_suf'] = df.apply(lambda x: (x["home_goals_suf_mean"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_goals_l5'] = df.apply(lambda x: (x["away_goals_mean_l5"]*x["rank_dif"]), axis =1)
df['home_weight_goals_suf_l5'] = df.apply(lambda x: (x["home_goals_suf_mean_l5"]*x["rank_dif"]), axis =1)

# %%
df.to_csv("data/new_model.csv", index=False)

# %%
df_model = df[(df.total_games_home > 5) & (df.total_games_away > 5)]

# %%
df_model.corr()
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_20584\4030759966.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_model.corr()
#                                rank_home  rank_away  home_score  away_score  \
# rank_home                       1.000000   0.434335   -0.241476    0.267769
# rank_away                       0.434335   1.000000    0.263715   -0.209504
# home_score                     -0.241476   0.263715    1.000000   -0.203761
# away_score                      0.267769  -0.209504   -0.203761    1.000000
# result                          0.157417  -0.179347   -0.531658    0.267532
# rank_dif                        0.540566  -0.523017   -0.474803    0.449048
# rank_change_home                0.016159  -0.005684   -0.025193    0.040412
# rank_change_away               -0.002367  -0.004487    0.017813    0.019637
# home_goals_mean                -0.638373  -0.234422    0.273094   -0.209814
# home_goals_mean_l5             -0.423104  -0.111132    0.214727   -0.151408
# home_goals_suf_mean             0.695654   0.241106   -0.212318    0.300173
# home_goals_suf_mean_l5          0.493026   0.139012   -0.185449    0.259058
# home_rank_mean                  0.745649   0.486964   -0.134478    0.132610
# home_rank_mean_l5               0.630424   0.448505   -0.084591    0.104295
# home_points_mean               -0.445571  -0.168518    0.191311   -0.141660
# home_points_mean_l5            -0.186449  -0.077359    0.106089   -0.119829
# away_goals_mean                -0.208353  -0.600088   -0.206244    0.229767
# away_goals_mean_l5             -0.089601  -0.390787   -0.169426    0.194626
# away_goals_suf_mean             0.261044   0.659048    0.265940   -0.171027
# away_goals_suf_mean_l5          0.168293   0.453418    0.206082   -0.133906
# away_rank_mean                  0.464133   0.756462    0.156771   -0.118841
# away_rank_mean_l5               0.448316   0.658509    0.110210   -0.075779
# away_points_mean               -0.150073  -0.393369   -0.137678    0.136517
# away_points_mean_l5            -0.038474  -0.161521   -0.093473    0.064824
# home_game_points_mean          -0.752094  -0.256620    0.263224   -0.266015
# home_game_points_mean_l5       -0.508703  -0.143005    0.220528   -0.217560
# home_game_points_rank_mean     -0.656467  -0.328735    0.201384   -0.157613
# home_game_points_rank_mean_l5  -0.422815  -0.205933    0.133386   -0.110320
# away_game_points_mean          -0.247939  -0.708115   -0.241594    0.218877
# away_game_points_mean_l5       -0.125988  -0.462132   -0.198162    0.178475
# away_game_points_rank_mean     -0.319744  -0.670219   -0.166699    0.188877
# away_game_points_rank_mean_l5  -0.215801  -0.424804   -0.111736    0.111157
# is_friendly_0                   0.054856  -0.041448   -0.031263    0.080489
# is_friendly_1                  -0.054856   0.041448    0.031263   -0.080489
# total_games_away               -0.125197  -0.306551   -0.079890    0.106059
# total_games_home               -0.280947  -0.111097    0.099405   -0.049584
# home_weight_goals               0.481315  -0.481263   -0.495924    0.378966
# away_weight_goals_suf           0.421999  -0.538683   -0.473400    0.376815
# home_weight_goals_l5            0.447927  -0.446591   -0.458419    0.350432
# away_weight_goals_suf_l5        0.412354  -0.504135   -0.450535    0.362127
# home_weight_points              0.480623  -0.499230   -0.490162    0.378314
# away_weight_points              0.530865  -0.445563   -0.403833    0.448022
# away_weight_goals               0.509974  -0.445710   -0.396206    0.454406
# home_weight_goals_suf           0.536533  -0.418371   -0.383013    0.459494
# away_weight_goals_l5            0.479948  -0.414676   -0.371386    0.424451
# home_weight_goals_suf_l5        0.502666  -0.399476   -0.356446    0.432623
#
#                                  result  rank_dif  rank_change_home  \
# rank_home                      0.157417  0.540566          0.016159
# rank_away                     -0.179347 -0.523017         -0.005684
# home_score                    -0.531658 -0.474803         -0.025193
# away_score                     0.267532  0.449048          0.040412
# result                         1.000000  0.316464          0.040521
# rank_dif                       0.316464  1.000000          0.020600
# rank_change_home               0.040521  0.020600          1.000000
# rank_change_away              -0.007080  0.001951         -0.062396
# home_goals_mean               -0.177560 -0.385100         -0.088782
# home_goals_mean_l5            -0.140153 -0.296559         -0.126997
# home_goals_suf_mean            0.156335  0.433059          0.076331
# home_goals_suf_mean_l5         0.125886  0.336681          0.173518
# home_rank_mean                 0.081396  0.250736         -0.062010
# home_rank_mean_l5              0.064951  0.177626         -0.038308
# home_points_mean              -0.125000 -0.264219         -0.171389
# home_points_mean_l5           -0.067157 -0.104171         -0.350499
# away_goals_mean                0.146808  0.363331          0.008197
# away_goals_mean_l5             0.121779  0.280211          0.022582
# away_goals_suf_mean           -0.160516 -0.368541          0.012179
# away_goals_suf_mean_l5        -0.124557 -0.264248          0.015632
# away_rank_mean                -0.105212 -0.267357         -0.038824
# away_rank_mean_l5             -0.065272 -0.190835         -0.037514
# away_points_mean               0.102662  0.225402          0.004245
# away_points_mean_l5            0.088663  0.114455          0.002165
# home_game_points_mean         -0.178282 -0.471974         -0.116512
# home_game_points_mean_l5      -0.143090 -0.347787         -0.243561
# home_game_points_rank_mean    -0.123950 -0.314133         -0.020957
# home_game_points_rank_mean_l5 -0.071067 -0.207740         -0.094286
# away_game_points_mean          0.166347  0.426770          0.001462
# away_game_points_mean_l5       0.143527  0.312417          0.018606
# away_game_points_rank_mean     0.129799  0.323431          0.021056
# away_game_points_rank_mean_l5  0.085547  0.192568          0.022712
# is_friendly_0                  0.026736  0.090619          0.003050
# is_friendly_1                 -0.026736 -0.090619         -0.003050
# total_games_away               0.058455  0.167853          0.013739
# total_games_home              -0.060267 -0.162077         -0.022452
# home_weight_goals              0.325941  0.904936          0.024621
# away_weight_goals_suf          0.298994  0.902440          0.009750
# home_weight_goals_l5           0.303301  0.840960          0.036830
# away_weight_goals_suf_l5       0.290402  0.861045         -0.001544
# home_weight_points             0.327459  0.921063          0.031411
# away_weight_points             0.277453  0.918479          0.021780
# away_weight_goals              0.264672  0.898848          0.019638
# home_weight_goals_suf          0.240959  0.898444          0.008700
# away_weight_goals_l5           0.248603  0.841451          0.017961
# home_weight_goals_suf_l5       0.225213  0.848751          0.001375
#
#                                rank_change_away  home_goals_mean  \
# rank_home                             -0.002367        -0.638373
# rank_away                             -0.004487        -0.234422
# home_score                             0.017813         0.273094
# away_score                             0.019637        -0.209814
# result                                -0.007080        -0.177560
# rank_dif                               0.001951        -0.385100
# rank_change_home                      -0.062396        -0.088782
# rank_change_away                       1.000000        -0.009581
# home_goals_mean                       -0.009581         1.000000
# home_goals_mean_l5                     0.016512         0.686040
# home_goals_suf_mean                    0.027290        -0.600746
# home_goals_suf_mean_l5                 0.022695        -0.445678
# home_rank_mean                        -0.022812        -0.248259
# home_rank_mean_l5                     -0.009172        -0.243432
# home_points_mean                      -0.016995         0.544696
# home_points_mean_l5                    0.011451         0.285615
# away_goals_mean                       -0.070199         0.205638
# away_goals_mean_l5                    -0.149226         0.113769
# away_goals_suf_mean                    0.051441        -0.173163
# away_goals_suf_mean_l5                 0.142546        -0.112222
# away_rank_mean                        -0.051247        -0.148487
# away_rank_mean_l5                     -0.031806        -0.163057
# away_points_mean                      -0.161472         0.123277
# away_points_mean_l5                   -0.344954         0.032895
# home_game_points_mean                 -0.021574         0.851267
# home_game_points_mean_l5               0.001218         0.612473
# home_game_points_rank_mean             0.006826         0.547958
# home_game_points_rank_mean_l5          0.018217         0.364482
# away_game_points_mean                 -0.091907         0.209244
# away_game_points_mean_l5              -0.247325         0.106203
# away_game_points_rank_mean            -0.005601         0.174673
# away_game_points_rank_mean_l5         -0.075776         0.112681
# is_friendly_0                          0.006859        -0.051567
# is_friendly_1                         -0.006859         0.051567
# total_games_away                      -0.017299         0.019605
# total_games_home                      -0.022512         0.127243
# home_weight_goals                     -0.010805        -0.408797
# away_weight_goals_suf                  0.006245        -0.289283
# home_weight_goals_l5                  -0.012810        -0.388589
# away_weight_goals_suf_l5               0.001973        -0.284052
# home_weight_points                    -0.006628        -0.369824
# away_weight_points                    -0.001854        -0.401978
# away_weight_goals                      0.004756        -0.385264
# home_weight_goals_suf                  0.016219        -0.368315
# away_weight_goals_l5                   0.005851        -0.359938
# home_weight_goals_suf_l5               0.025041        -0.344274
#
#                                home_goals_mean_l5  ...  home_weight_goals  \
# rank_home                               -0.423104  ...           0.481315
# rank_away                               -0.111132  ...          -0.481263
# home_score                               0.214727  ...          -0.495924
# away_score                              -0.151408  ...           0.378966
# result                                  -0.140153  ...           0.325941
# rank_dif                                -0.296559  ...           0.904936
# rank_change_home                        -0.126997  ...           0.024621
# rank_change_away                         0.016512  ...          -0.010805
# home_goals_mean                          0.686040  ...          -0.408797
# home_goals_mean_l5                       1.000000  ...          -0.323795
# home_goals_suf_mean                     -0.399083  ...           0.356411
# home_goals_suf_mean_l5                  -0.410055  ...           0.269640
# home_rank_mean                          -0.148109  ...           0.247942
# home_rank_mean_l5                        0.069809  ...           0.177693
# home_points_mean                         0.357737  ...          -0.270031
# home_points_mean_l5                      0.332386  ...          -0.111677
# away_goals_mean                          0.124947  ...           0.350024
# away_goals_mean_l5                       0.106933  ...           0.262338
# away_goals_suf_mean                     -0.079540  ...          -0.341899
# away_goals_suf_mean_l5                  -0.057243  ...          -0.251401
# away_rank_mean                          -0.047140  ...          -0.240708
# away_rank_mean_l5                       -0.020521  ...          -0.175895
# away_points_mean                         0.059524  ...           0.226907
# away_points_mean_l5                      0.013311  ...           0.111852
# home_game_points_mean                    0.584290  ...          -0.448221
# home_game_points_mean_l5                 0.749818  ...          -0.339159
# home_game_points_rank_mean               0.354474  ...          -0.351803
# home_game_points_rank_mean_l5            0.226562  ...          -0.235621
# away_game_points_mean                    0.117731  ...           0.404941
# away_game_points_mean_l5                 0.085868  ...           0.297515
# away_game_points_rank_mean               0.089973  ...           0.317039
# away_game_points_rank_mean_l5            0.054076  ...           0.192863
# is_friendly_0                           -0.010227  ...           0.063257
# is_friendly_1                            0.010227  ...          -0.063257
# total_games_away                         0.037039  ...           0.139328
# total_games_home                         0.112571  ...          -0.155738
# home_weight_goals                       -0.323795  ...           1.000000
# away_weight_goals_suf                   -0.228507  ...           0.847062
# home_weight_goals_l5                    -0.398900  ...           0.928671
# away_weight_goals_suf_l5                -0.222016  ...           0.801815
# home_weight_points                      -0.292821  ...           0.978330
# away_weight_points                      -0.308310  ...           0.799079
# away_weight_goals                       -0.293821  ...           0.784602
# home_weight_goals_suf                   -0.275052  ...           0.683758
# away_weight_goals_l5                    -0.275356  ...           0.725873
# home_weight_goals_suf_l5                -0.253169  ...           0.648675
#
#                                away_weight_goals_suf  home_weight_goals_l5  \
# rank_home                                   0.421999              0.447927
# rank_away                                  -0.538683             -0.446591
# home_score                                 -0.473400             -0.458419
# away_score                                  0.376815              0.350432
# result                                      0.298994              0.303301
# rank_dif                                    0.902440              0.840960
# rank_change_home                            0.009750              0.036830
# rank_change_away                            0.006245             -0.012810
# home_goals_mean                            -0.289283             -0.388589
# home_goals_mean_l5                         -0.228507             -0.398900
# home_goals_suf_mean                         0.338487              0.335939
# home_goals_suf_mean_l5                      0.261348              0.259144
# home_rank_mean                              0.206344              0.225364
# home_rank_mean_l5                           0.144190              0.137067
# home_points_mean                           -0.187736             -0.266682
# home_points_mean_l5                        -0.076775             -0.121915
# away_goals_mean                             0.366982              0.324859
# away_goals_mean_l5                          0.275097              0.242213
# away_goals_suf_mean                        -0.490568             -0.321387
# away_goals_suf_mean_l5                     -0.347995             -0.234510
# away_rank_mean                             -0.242154             -0.222398
# away_rank_mean_l5                          -0.172532             -0.166424
# away_points_mean                            0.219080              0.205207
# away_points_mean_l5                         0.117675              0.101687
# home_game_points_mean                      -0.351322             -0.422465
# home_game_points_mean_l5                   -0.264851             -0.357751
# home_game_points_rank_mean                 -0.244783             -0.319272
# home_game_points_rank_mean_l5              -0.164364             -0.200669
# away_game_points_mean                       0.452648              0.373021
# away_game_points_mean_l5                    0.328743              0.271249
# away_game_points_rank_mean                  0.277993              0.297248
# away_game_points_rank_mean_l5               0.167076              0.181212
# is_friendly_0                               0.032062              0.056226
# is_friendly_1                              -0.032062             -0.056226
# total_games_away                            0.138451              0.107356
# total_games_home                           -0.134987             -0.165900
# home_weight_goals                           0.847062              0.928671
# away_weight_goals_suf                       1.000000              0.786140
# home_weight_goals_l5                        0.786140              1.000000
# away_weight_goals_suf_l5                    0.937722              0.743491
# home_weight_points                          0.851526              0.905468
# away_weight_points                          0.686451              0.744413
# away_weight_goals                           0.686941              0.732704
# home_weight_goals_suf                       0.791791              0.640404
# away_weight_goals_l5                        0.644419              0.680885
# home_weight_goals_suf_l5                    0.743831              0.581000
#
#                                away_weight_goals_suf_l5  home_weight_points  \
# rank_home                                      0.412354            0.480623
# rank_away                                     -0.504135           -0.499230
# home_score                                    -0.450535           -0.490162
# away_score                                     0.362127            0.378314
# result                                         0.290402            0.327459
# rank_dif                                       0.861045            0.921063
# rank_change_home                              -0.001544            0.031411
# rank_change_away                               0.001973           -0.006628
# home_goals_mean                               -0.284052           -0.369824
# home_goals_mean_l5                            -0.222016           -0.292821
# home_goals_suf_mean                            0.324319            0.356328
# home_goals_suf_mean_l5                         0.246105            0.267454
# home_rank_mean                                 0.208725            0.238930
# home_rank_mean_l5                              0.156419            0.173923
# home_points_mean                              -0.185906           -0.278243
# home_points_mean_l5                           -0.075746           -0.113526
# away_goals_mean                                0.340198            0.367371
# away_goals_mean_l5                             0.270383            0.273762
# away_goals_suf_mean                           -0.444577           -0.341927
# away_goals_suf_mean_l5                        -0.386042           -0.247299
# away_rank_mean                                -0.220629           -0.246274
# away_rank_mean_l5                             -0.127790           -0.180944
# away_points_mean                               0.199006            0.233213
# away_points_mean_l5                            0.116355            0.109685
# home_game_points_mean                         -0.339962           -0.447394
# home_game_points_mean_l5                      -0.247908           -0.334040
# home_game_points_rank_mean                    -0.233952           -0.340464
# home_game_points_rank_mean_l5                 -0.158036           -0.231484
# away_game_points_mean                          0.419878            0.420283
# away_game_points_mean_l5                       0.331958            0.305467
# away_game_points_rank_mean                     0.266941            0.329973
# away_game_points_rank_mean_l5                  0.164765            0.205993
# is_friendly_0                                  0.031282            0.065341
# is_friendly_1                                 -0.031282           -0.065341
# total_games_away                               0.129205            0.143438
# total_games_home                              -0.132847           -0.159803
# home_weight_goals                              0.801815            0.978330
# away_weight_goals_suf                          0.937722            0.851526
# home_weight_goals_l5                           0.743491            0.905468
# away_weight_goals_suf_l5                       1.000000            0.804326
# home_weight_points                             0.804326            1.000000
# away_weight_points                             0.664448            0.816861
# away_weight_goals                              0.662917            0.794904
# home_weight_goals_suf                          0.766060            0.679821
# away_weight_goals_l5                           0.595914            0.735861
# home_weight_goals_suf_l5                       0.720597            0.646653
#
#                                away_weight_points  away_weight_goals  \
# rank_home                                0.530865           0.509974
# rank_away                               -0.445563          -0.445710
# home_score                              -0.403833          -0.396206
# away_score                               0.448022           0.454406
# result                                   0.277453           0.264672
# rank_dif                                 0.918479           0.898848
# rank_change_home                         0.021780           0.019638
# rank_change_away                        -0.001854           0.004756
# home_goals_mean                         -0.401978          -0.385264
# home_goals_mean_l5                      -0.308310          -0.293821
# home_goals_suf_mean                      0.425668           0.415224
# home_goals_suf_mean_l5                   0.341328           0.338003
# home_rank_mean                           0.236134           0.235360
# home_rank_mean_l5                        0.163213           0.160971
# home_points_mean                        -0.281735          -0.271713
# home_points_mean_l5                     -0.106364          -0.105393
# away_goals_mean                          0.317169           0.331958
# away_goals_mean_l5                       0.248182           0.259046
# away_goals_suf_mean                     -0.259039          -0.273799
# away_goals_suf_mean_l5                  -0.186647          -0.198614
# away_rank_mean                          -0.262918          -0.265946
# away_rank_mean_l5                       -0.192306          -0.191940
# away_points_mean                         0.214600           0.215196
# away_points_mean_l5                      0.100466           0.102407
# home_game_points_mean                   -0.481950          -0.457542
# home_game_points_mean_l5                -0.356308          -0.340913
# home_game_points_rank_mean              -0.316405          -0.303344
# home_game_points_rank_mean_l5           -0.202864          -0.193034
# away_game_points_mean                    0.354833           0.362592
# away_game_points_mean_l5                 0.259609           0.267675
# away_game_points_rank_mean               0.331910           0.339496
# away_game_points_rank_mean_l5            0.194782           0.192805
# is_friendly_0                            0.134418           0.128619
# is_friendly_1                           -0.134418          -0.128619
# total_games_away                         0.172664           0.171668
# total_games_home                        -0.151128          -0.141921
# home_weight_goals                        0.799079           0.784602
# away_weight_goals_suf                    0.686451           0.686941
# home_weight_goals_l5                     0.744413           0.732704
# away_weight_goals_suf_l5                 0.664448           0.662917
# home_weight_points                       0.816861           0.794904
# away_weight_points                       1.000000           0.978329
# away_weight_goals                        0.978329           1.000000
# home_weight_goals_suf                    0.853230           0.847733
# away_weight_goals_l5                     0.914802           0.933567
# home_weight_goals_suf_l5                 0.808578           0.802296
#
#                                home_weight_goals_suf  away_weight_goals_l5  \
# rank_home                                   0.536533              0.479948
# rank_away                                  -0.418371             -0.414676
# home_score                                 -0.383013             -0.371386
# away_score                                  0.459494              0.424451
# result                                      0.240959              0.248603
# rank_dif                                    0.898444              0.841451
# rank_change_home                            0.008700              0.017961
# rank_change_away                            0.016219              0.005851
# home_goals_mean                            -0.368315             -0.359938
# home_goals_mean_l5                         -0.275052             -0.275356
# home_goals_suf_mean                         0.493624              0.399085
# home_goals_suf_mean_l5                      0.394315              0.317419
# home_rank_mean                              0.233217              0.218149
# home_rank_mean_l5                           0.160923              0.154632
# home_points_mean                           -0.230695             -0.248779
# home_points_mean_l5                        -0.089660             -0.096102
# away_goals_mean                             0.280876              0.305070
# away_goals_mean_l5                          0.232431              0.248640
# away_goals_suf_mean                        -0.300847             -0.257571
# away_goals_suf_mean_l5                     -0.214991             -0.169666
# away_rank_mean                             -0.228002             -0.249050
# away_rank_mean_l5                          -0.149983             -0.187218
# away_points_mean                            0.166277              0.206993
# away_points_mean_l5                         0.096139              0.090020
# home_game_points_mean                      -0.451914             -0.429254
# home_game_points_mean_l5                   -0.328917             -0.316698
# home_game_points_rank_mean                 -0.255298             -0.277679
# home_game_points_rank_mean_l5              -0.160676             -0.178744
# away_game_points_mean                       0.328332              0.333232
# away_game_points_mean_l5                    0.248212              0.229072
# away_game_points_rank_mean                  0.249006              0.311747
# away_game_points_rank_mean_l5               0.131895              0.168450
# is_friendly_0                               0.093266              0.122843
# is_friendly_1                              -0.093266             -0.122843
# total_games_away                            0.158550              0.185978
# total_games_home                           -0.130185             -0.103590
# home_weight_goals                           0.683758              0.725873
# away_weight_goals_suf                       0.791791              0.644419
# home_weight_goals_l5                        0.640404              0.680885
# away_weight_goals_suf_l5                    0.766060              0.595914
# home_weight_points                          0.679821              0.735861
# away_weight_points                          0.853230              0.914802
# away_weight_goals                           0.847733              0.933567
# home_weight_goals_suf                       1.000000              0.806706
# away_weight_goals_l5                        0.806706              1.000000
# home_weight_goals_suf_l5                    0.940856              0.762649
#
#                                home_weight_goals_suf_l5
# rank_home                                      0.502666
# rank_away                                     -0.399476
# home_score                                    -0.356446
# away_score                                     0.432623
# result                                         0.225213
# rank_dif                                       0.848751
# rank_change_home                               0.001375
# rank_change_away                               0.025041
# home_goals_mean                               -0.344274
# home_goals_mean_l5                            -0.253169
# home_goals_suf_mean                            0.462438
# home_goals_suf_mean_l5                         0.402999
# home_rank_mean                                 0.219749
# home_rank_mean_l5                              0.141407
# home_points_mean                              -0.220263
# home_points_mean_l5                           -0.076056
# away_goals_mean                                0.273377
# away_goals_mean_l5                             0.219014
# away_goals_suf_mean                           -0.277794
# away_goals_suf_mean_l5                        -0.202968
# away_rank_mean                                -0.217960
# away_rank_mean_l5                             -0.150562
# away_points_mean                               0.167700
# away_points_mean_l5                            0.085048
# home_game_points_mean                         -0.424203
# home_game_points_mean_l5                      -0.297277
# home_game_points_rank_mean                    -0.247144
# home_game_points_rank_mean_l5                 -0.162316
# away_game_points_mean                          0.313334
# away_game_points_mean_l5                       0.229264
# away_game_points_rank_mean                     0.234674
# away_game_points_rank_mean_l5                  0.119638
# is_friendly_0                                  0.085672
# is_friendly_1                                 -0.085672
# total_games_away                               0.160521
# total_games_home                              -0.117827
# home_weight_goals                              0.648675
# away_weight_goals_suf                          0.743831
# home_weight_goals_l5                           0.581000
# away_weight_goals_suf_l5                       0.720597
# home_weight_points                             0.646653
# away_weight_points                             0.808578
# away_weight_goals                              0.802296
# home_weight_goals_suf                          0.940856
# away_weight_goals_l5                           0.762649
# home_weight_goals_suf_l5                       1.000000
#
# [46 rows x 46 columns]
