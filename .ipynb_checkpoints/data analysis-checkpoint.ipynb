# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Data analysis here will be different than old project
#
# Target variable is continuous, so we need to analyse relationship between continuous-continuous and discrete-continuous variables
#
# Also need to analyse the case of Home Team Goals and Away Team Goals

# %%
df = pd.read_csv("data/new_model.csv")

# %%
df.date = pd.to_datetime(df.date)

# %%
df[(df.home_team == 'Hungary') | (df.away_team == 'Hungary')][['home_team', 'home_score', 'away_score', 'home_goals_mean_l5', 'away_goals_mean_l5']]
# Out:
#                 home_team  home_score  away_score  home_goals_mean_l5  \
# 3                 Hungary         1.0         0.0            0.000000
# 107               Hungary         1.0         2.0            0.500000
# 162                 Wales         2.0         0.0            1.333333
# 225                Turkey         0.0         1.0            1.000000
# 251               Hungary         2.0         3.0            0.600000
# 300              Bulgaria         1.0         3.0            0.400000
# 336                Serbia         0.0         1.0            1.600000
# 381                Russia         0.0         0.0            2.600000
# 417               Hungary         2.0         1.0            1.400000
# 471               Hungary         1.0         1.0            1.600000
# 530               Hungary         2.0         0.0            1.400000
# 603               Hungary         3.0         3.0            1.200000
# 655            San Marino         0.0         3.0            0.000000
# 716               Andorra         1.0         4.0            0.200000
# 782               Hungary         1.0         0.0            2.600000
# 842               Hungary         0.0         0.0            2.600000
# 918               Hungary         0.0         3.0            2.200000
# 936               Hungary         1.0         1.0            1.600000
# 955               Germany         2.0         2.0            2.600000
# 1096              Hungary         0.0         4.0            0.800000
# 1147              Albania         1.0         0.0            0.800000
# 1205              Hungary         2.0         1.0            0.600000
# 1282              Hungary         0.0         1.0            1.000000
# 1344              England         1.0         1.0            3.000000
# 1422              Hungary         4.0         0.0            0.600000
# 1469               Poland         1.0         2.0            3.600000
# 1704              Hungary         0.0         1.0            1.800000
# 1799     Northern Ireland         0.0         1.0            1.000000
# 1889              Hungary         1.0         0.0            1.600000
# 1939                Italy         2.0         1.0            0.800000
# 2012              Hungary         1.0         1.0            1.000000
# 2061              England         0.0         4.0            2.600000
# 2146              Germany         0.0         1.0            1.800000
# 2192              Hungary         0.0         2.0            1.600000
# 2280           Luxembourg         2.0         2.0            1.400000
# 2312              Hungary         2.0         1.0            1.600000
# 2459              Hungary         1.0         0.0            1.800000
# 2559              Hungary         3.0         0.0            1.200000
# 2667           Montenegro         0.0         0.0            0.600000
# 2731              Hungary         2.0         0.0            1.600000
# 2836               Serbia         1.0         2.0            2.000000
# 2885              Hungary         1.0         1.0            1.600000
# 3017              Hungary         2.0         1.0            1.600000
# 3091            Lithuania         2.0         2.0            1.200000
# 3137             Bulgaria         2.0         2.0            0.400000
# 3184              Hungary         3.0         1.0            1.800000
# 3444              Hungary         1.0         0.0            2.000000
# 3519              Hungary         2.0         0.0            2.000000
# 3550  Republic of Ireland         2.0         1.0            1.000000
# 3621              Hungary         3.0         0.0            1.800000
# 3704              Hungary         1.0         3.0            2.000000
#
#       away_goals_mean_l5
# 3               3.000000
# 107             1.000000
# 162             0.666667
# 225             0.500000
# 251             3.600000
# 300             1.000000
# 336             1.400000
# 381             1.400000
# 417             0.800000
# 471             1.000000
# 530             2.400000
# 603             1.200000
# 655             1.600000
# 716             2.200000
# 782             0.600000
# 842             1.400000
# 918             2.000000
# 936             2.000000
# 955             1.200000
# 1096            2.000000
# 1147            0.600000
# 1205            0.800000
# 1282            1.600000
# 1344            0.800000
# 1422            0.200000
# 1469            1.400000
# 1704            2.200000
# 1799            1.400000
# 1889            4.600000
# 1939            1.600000
# 2012            1.800000
# 2061            0.800000
# 2146            1.600000
# 2192            1.200000
# 2280            1.400000
# 2312            2.000000
# 2459            1.800000
# 2559            1.600000
# 2667            1.600000
# 2731            0.200000
# 2836            1.600000
# 2885            2.200000
# 3017            2.000000
# 3091            1.400000
# 3137            1.800000
# 3184            2.000000
# 3444            2.200000
# 3519            1.200000
# 3550            2.000000
# 3621            1.000000
# 3704            1.200000

# %%
# Out:
# 1.6

# %%
(1+3+1+2+1)/5
# Out:
# 1.6

# %%
possible_features = ["rank_home", "rank_away"] + df.columns[8:25].tolist() + df.columns[37:-2].tolist()

# %%
df['total_games_home'] = df.apply(lambda x: len(df[(df.home_team == x["home_team"]) & (df.date < x["date"])])+len(df[(df.away_team == x["home_team"]) & (df.date < x["date"])]), axis=1)

# %%
df['total_games_away'] = df.apply(lambda x: len(df[(df.home_team == x["away_team"]) & (df.date < x["date"])])+len(df[(df.away_team == x["away_team"]) & (df.date < x["date"])]), axis=1)

# %%
df_model = df[(df.total_games_home > 5) & (df.total_games_away > 5)]

# %%
#df_model = df_model[(df_model.home_score < 7) & (df_model.away_score < 7)]

# %%
df_model[["home_team", "away_team", "home_score", "away_score", "home_goals_mean", "home_goals_mean_l5"]]
# Out:
#                home_team               away_team  home_score  away_score  \
# 206                 Iraq                 Bahrain         2.0         2.0
# 208              Bahrain            Saudi Arabia         1.0         0.0
# 316                Spain             Switzerland         1.0         0.0
# 317              Ukraine                 Germany         1.0         2.0
# 318           Luxembourg                  Cyprus         2.0         0.0
# ...                  ...                     ...         ...         ...
# 3685           Australia               Palestine         5.0         0.0
# 3686                Cuba          Cayman Islands         3.0         0.0
# 3687              Guyana                  Belize         3.0         1.0
# 3688  Dominican Republic  British Virgin Islands         4.0         0.0
# 3689         Puerto Rico                Anguilla         8.0         0.0
#
#       home_goals_mean  home_goals_mean_l5
# 206          1.714286                 1.2
# 208          1.125000                 1.2
# 316          2.714286                 3.4
# 317          1.428571                 1.2
# 318          0.714286                 1.0
# ...               ...                 ...
# 3685         1.829268                 2.8
# 3686         1.107143                 0.4
# 3687         2.000000                 2.2
# 3688         1.375000                 0.8
# 3689         2.590909                 2.0
#
# [3009 rows x 6 columns]

# %% [markdown]
# ### Home Team
#
# - Regression Line -> find most correlated
# - KDE plot -> not visible correlation, but significant changes in distribution

# %%
target = 'home_score'

# %%
df_feats = df_model[[target] + possible_features]

# %%
possible_features[10:20]
# Out:
# ['home_rank_mean_l5',
#  'home_points_mean',
#  'home_points_mean_l5',
#  'away_goals_mean',
#  'away_goals_mean_l5',
#  'away_goals_suf_mean',
#  'away_goals_suf_mean_l5',
#  'away_rank_mean',
#  'away_rank_mean_l5',
#  'total_games_away']

# %%
#for i in [10, 20, 29]:
g = sns.pairplot(df_feats, kind="reg", diag_kind=None,
            y_vars = [target],
            x_vars = possible_features[:10],
            )
g.fig.set_size_inches(25,5)

# %%
#for i in [10, 20, 29]:
g = sns.pairplot(df_feats, kind="reg", diag_kind=None,
            y_vars = [target],
            x_vars = possible_features[10:20],
            )
g.fig.set_size_inches(25,5)

# %%
#for i in [10, 20, 29]:
g = sns.pairplot(df_feats, kind="reg", diag_kind=None,
            y_vars = [target],
            x_vars = possible_features[20:],
            )
g.fig.set_size_inches(25,5)

# %% [markdown]
# rank_dif -> visible relantionship
#
#
# below we can evaluate to see if their values are impacting in the distribution of the home goals:
#
#  'home_weight_goals',
#  'away_weight_goals_suf',
#  'home_weight_goals_l5',
#  'away_weight_goals_suf_l5',
#  'home_weight_points',
#  'away_weight_points',
#
# Since goals is a continuous variable that follows a poisson distribution, with very limited values, using only a regression to select the variables is very unuseful. I'll analyse also the distributions

# %%
pos_cols = [['home_weight_goals','home_weight_goals_l5',],
            ['away_weight_goals_suf','away_weight_goals_suf_l5',],
            ['home_weight_points','away_weight_points',]]

# %%
f, axes = plt.subplots(3, 2, figsize=(15, 18))

for (ax, pc) in zip(axes, pos_cols):
    sns.kdeplot(data = df_feats, x = pc[0], hue = target, fill=True, warn_singular=False, ax=ax[0])
    sns.kdeplot(data = df_feats, x = pc[1], hue = target, fill=True, warn_singular=False, ax=ax[1])

# %%
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'rank_home', 'rank_away',
#        'home_score', 'away_score', 'result', 'rank_dif', 'rank_change_home',
#        'rank_change_away', 'home_goals_mean', 'home_goals_mean_l5',
#        'home_goals_suf_mean', 'home_goals_suf_mean_l5', 'home_rank_mean',
#        'home_rank_mean_l5', 'home_points_mean', 'home_points_mean_l5',
#        'away_goals_mean', 'away_goals_mean_l5', 'away_goals_suf_mean',
#        'away_goals_suf_mean_l5', 'away_rank_mean', 'away_rank_mean_l5',
#        'away_points_mean', 'away_points_mean_l5', 'home_game_points_mean',
#        'home_game_points_mean_l5', 'home_game_points_rank_mean',
#        'home_game_points_rank_mean_l5', 'away_game_points_mean',
#        'away_game_points_mean_l5', 'away_game_points_rank_mean',
#        'away_game_points_rank_mean_l5', 'is_friendly_0', 'is_friendly_1',
#        'total_games_away', 'total_games_home', 'home_weight_goals',
#        'away_weight_goals_suf', 'home_weight_goals_l5',
#        'away_weight_goals_suf_l5', 'home_weight_points', 'away_weight_points',
#        'away_weight_goals', 'home_weight_goals_suf', 'away_weight_goals_l5',
#        'home_weight_goals_suf_l5'],
#       dtype='object')

# %%
home_cols = ["home_weight_goals", "away_weight_goals_suf", 'home_weight_points','away_weight_points',"home_goals_mean_l5", "away_goals_suf_mean_l5", "home_game_points_mean_l5", "away_game_points_mean_l5"]

# %%
df_model[["home_score"]+home_cols].to_csv("data/home_db.csv", index=False)

# %% [markdown]
# ### Away Team
#
# - Regression Line -> find most correlated
# - KDE plot -> not visible correlation, but significant changes in distribution

# %%
target = 'away_score'

# %%
df_feats = df_model[[target] + possible_features]

# %%
sns.pairplot(df_feats, kind="reg", diag_kind=None,
            y_vars = [target],
            x_vars = possible_features)

# %%
pos_cols = [['away_weight_goals','home_weight_goals_suf',],
            ['home_weight_points','away_weight_points',]]

# %%
f, axes = plt.subplots(2, 2, figsize=(15, 18))

for (ax, pc) in zip(axes, pos_cols):
    sns.kdeplot(data = df_feats, x = pc[0], hue = target, fill=True, warn_singular=False, ax=ax[0])
    sns.kdeplot(data = df_feats, x = pc[1], hue = target, fill=True, warn_singular=False, ax=ax[1])

# %%
away_cols = ['away_weight_goals','home_weight_goals_suf','home_weight_points','away_weight_points',"away_goals_mean_l5", "home_goals_suf_mean_l5", "home_game_points_mean_l5", "away_game_points_mean_l5"]

# %%
df_model[["away_score"]+away_cols].to_csv("data/away_db.csv", index=False)
